# %% [markdown]
# # Week 1 — Linear Regression (Day 3)
#
# This notebook marks the beginning of my AI Research journey.
#
# **Goals:**
# - Understand Linear Regression
# - Visualize data
# - Implement a regression model
# - Prepare for experiment logging

# %%
# SETUP
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

seed = 42
np.random.seed(seed)

print('Environment ready!')

# %% [markdown]
# ## Generate a Simple Dataset
# For learning purposes, we create a synthetic (fake) dataset.

# %%
# Simple synthetic dataset
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

plt.scatter(X, y)
plt.title('Sample Data')
plt.show()
